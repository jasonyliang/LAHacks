# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import os
import cv2
from PIL import Image
import base64
import json

# %%
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FPS, 30)
ret, frame = cap.read()


while True:
    cv2.imshow('img',frame)
    if cv2.waitKey(1) & 0xFF == ord('y'):
        break
cv2.destroyAllWindows()
cap.release()

# %%
os.chdir('C://Users//Ryan_Siv//Documents//GitHub//LAHacks//game')

# %%
head, curr_dir = os.path.split(os.getcwd())
api_key = 'My First Project-e65c2d409577.json'
file = os.path.join(head, api_key)
file
# Out:
# 'C:\\Users\\Ryan_Siv\\Documents\\GitHub\\LAHacks\\My First Project-e65c2d409577.json'

# %%
## Setting up google API
import os
from google.oauth2 import service_account
def authenticate():
    head, curr_dir = os.path.split(os.getcwd())
    api_key = 'My First Project-e65c2d409577.json'
    file = os.path.join(head, api_key)
    credentials = service_account.Credentials.from_service_account_file(file)
    return credentials

# %%
credentials = authenticate()

# %%
## import test image
temp_pic_path = 'D:\Misc Projects\AutoSombrero'
pic_name = 'jason.jpg'
jason = cv2.imread(os.path.join(temp_pic_path, pic_name))

# %%
plt.imshow(jason)

# %%
from google.cloud import vision
from google.cloud.vision import types

# %%
import base64
from io import BytesIO

buffered = BytesIO()
image.save(buffered, format="JPEG")
img_str = base64.b64encode(buffered.getvalue())

# %%
ret, buffer = cv2.imencode('.jpg', jason)
jpg_as_text = base64.b64encode(buffer)
jpg_as_np = np.frombuffer(jpg_as_text, dtype=np.uint8)
image_buffer = cv2.imdecode(jpg_as_np, flags=1)

# %%
jason

# %%
jason
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-186-cf96da4e54d4> in <module>()
#       1 client = vision.ImageAnnotatorClient(credentials = credentials)
# ----> 2 response = client.face_detection(jpg_as_text)
#       3 faces = response.face_annotations
#
# ~\Anaconda3\lib\site-packages\google\cloud\vision_helpers\decorators.py in inner(self, image, retry, timeout, **kwargs)
#     108             **kwargs
#     109         )
# --> 110         return self.annotate_image(request, retry=retry, timeout=timeout)
#     111
#     112     # Set the appropriate function metadata.
#
# ~\Anaconda3\lib\site-packages\google\cloud\vision_helpers\__init__.py in annotate_image(self, request, retry, timeout)
#      56
#      57         # If a filename is provided, read the file.
# ---> 58         filename = protobuf.get(image, 'source.filename', default=None)
# ...

# %%
isinstance(bytes_im, (bytes, bytearray))
# Out:
# True

# %%
client = vision.ImageAnnotatorClient(credentials = credentials)
content = cv2.imencode('.jpg', jason)[1].tostring()
img = types.Image(content=content)
response = client.face_detection(image = img)
faces = response.face_annotations

# %%
def google_vision_api():
    """
    Creates instance of ImageAnnotaterClient. Returns refrence to instance
    """
    credentials = authenticate()
    client = vision.ImageAnnotatorClient(credentials = credentials)
    return client

# %%
def process_opencv(image, credentials):
    """
    Takes image from 
    """
    client = vision.ImageAnnotatorClient(credentials = credentials)
    content = cv2.imencode('.jpg', jason)[1].tostring()
    img = types.Image(content=content)
    response = client.face_detection(image = img)
    faces = response.face_annotations
    Nose_tip_coords = faces[0].landmarks[7]
    return((Nose_tip_coords.position.x,Nose_tip_coords.position.y,Nose_tip_coords.position.z))

# %%
client = google_vision_api()
nose_coords = process_opencv(image = jason,credentials = client)
# Out:
# ERROR:root:AuthMetadataPluginCallback "<google.auth.transport.grpc.AuthMetadataPlugin object at 0x0000012AE55FE160>" raised exception!
# Traceback (most recent call last):
#   File "C:\Users\Ryan_Siv\Anaconda3\lib\site-packages\grpc\_plugin_wrapping.py", line 77, in __call__
#     callback_state, callback))
#   File "C:\Users\Ryan_Siv\Anaconda3\lib\site-packages\google\auth\transport\grpc.py", line 77, in __call__
#     callback(self._get_authorization_headers(context), None)
#   File "C:\Users\Ryan_Siv\Anaconda3\lib\site-packages\google\auth\transport\grpc.py", line 61, in _get_authorization_headers
#     self._credentials.before_request(
# AttributeError: 'ImageAnnotatorClient' object has no attribute 'before_request'
# ---------------------------------------------------------------------------
# _Rendezvous                               Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\google\api_core\grpc_helpers.py in error_remapped_callable(*args, **kwargs)
# ...

# %%
Nose_tip_coords = faces[0].landmarks[7]
Nose_tip_coords.position.x
# Out:
# 227.22994995117188

# %%
# Out:
# type: NOSE_TIP
# position {
#   x: 227.22994995117188
#   y: 245.60812377929688
#   z: -46.63679885864258
# }
